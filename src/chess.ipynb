# %% [markdown]
# Objetivo dessa bagaça é arrumar a cagada da fide

# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print('import completo!')
# Out:
# import completo!

# %% [markdown]
# Os arquivos estão localizados no meu git, o código abaixo é só para testar a conexão com eles.

# %%
test_data_path = 'https://raw.githubusercontent.com/GyaRyu/chessdata/master/data/btz/blitz_apr13frl.txt'
test_data = pd.read_fwf(test_data_path)
test_data.head()
# Out:
#    ID Number                   Name  Fed Sex  Tit  ... apr13 Gms   K  B-day  Flag
# 0    5027942     Aaditya, Jagadeesh  IND   M  NaN  ...  1800   0  20   1998   NaN
# 1   25021044  Aagney L., Narasimhan  IND   M  NaN  ...  1279   0  20   2000   NaN
# 2     501956          Aaltio, Erkki  FIN   M  NaN  ...  2068   0  20   1935   NaN
# 3   35029185              Aan Sikka  IND   M  NaN  ...  1384   0  20   2003   NaN
# 4   25024981            Aansh Gupta  IND   M  NaN  ...  1710   0  20   2002   NaN
#
# [5 rows x 12 columns]

# %% [markdown]
# Agora é necessário a sigla dos meses e os anos que a fide publicou os rating para blitz.

# %%
#template path https://raw.githubusercontent.com/GyaRyu/chessdata/master/data/btz/blitz_(month)(year)frl.txt
months  = ['jan','feb','mar','apr','may','jun','jul','aug','sep','oct','nov','dec']
years   = [str(n) for n in range(13,20)]
print(months)
print(years)
# Out:
# ['jan', 'feb', 'mar', 'apr', 'may', 'jun', 'jul', 'aug', 'sep', 'oct', 'nov', 'dec']
# ['13', '14', '15', '16', '17', '18', '19']

# %% [markdown]
# Logo depois a variável 'dates' ira armazenar todos as datas das publicações.

# %%
dates = []
for year in years:
  for month in months:
    dates.append(month+year)
    pass
  pass
dates.append('jan20')
print(dates)
print(len(dates))
# Out:
# ['jan13', 'feb13', 'mar13', 'apr13', 'may13', 'jun13', 'jul13', 'aug13', 'sep13', 'oct13', 'nov13', 'dec13', 'jan14', 'feb14', 'mar14', 'apr14', 'may14', 'jun14', 'jul14', 'aug14', 'sep14', 'oct14', 'nov14', 'dec14', 'jan15', 'feb15', 'mar15', 'apr15', 'may15', 'jun15', 'jul15', 'aug15', 'sep15', 'oct15', 'nov15', 'dec15', 'jan16', 'feb16', 'mar16', 'apr16', 'may16', 'jun16', 'jul16', 'aug16', 'sep16', 'oct16', 'nov16', 'dec16', 'jan17', 'feb17', 'mar17', 'apr17', 'may17', 'jun17', 'jul17', 'aug17', 'sep17', 'oct17', 'nov17', 'dec17', 'jan18', 'feb18', 'mar18', 'apr18', 'may18', 'jun18', 'jul18', 'aug18', 'sep18', 'oct18', 'nov18', 'dec18', 'jan19', 'feb19', 'mar19', 'apr19', 'may19', 'jun19', 'jul19', 'aug19', 'sep19', 'oct19', 'nov19', 'dec19', 'jan20']
# 85

# %% [markdown]
# Finalmente a variável files irá armazenar o nome de todos os arquivos.

# %%
files = ['blitz_'+date+'frl.txt' for date in dates]
print(files)
# Out:
# ['blitz_jan13frl.txt', 'blitz_feb13frl.txt', 'blitz_mar13frl.txt', 'blitz_apr13frl.txt', 'blitz_may13frl.txt', 'blitz_jun13frl.txt', 'blitz_jul13frl.txt', 'blitz_aug13frl.txt', 'blitz_sep13frl.txt', 'blitz_oct13frl.txt', 'blitz_nov13frl.txt', 'blitz_dec13frl.txt', 'blitz_jan14frl.txt', 'blitz_feb14frl.txt', 'blitz_mar14frl.txt', 'blitz_apr14frl.txt', 'blitz_may14frl.txt', 'blitz_jun14frl.txt', 'blitz_jul14frl.txt', 'blitz_aug14frl.txt', 'blitz_sep14frl.txt', 'blitz_oct14frl.txt', 'blitz_nov14frl.txt', 'blitz_dec14frl.txt', 'blitz_jan15frl.txt', 'blitz_feb15frl.txt', 'blitz_mar15frl.txt', 'blitz_apr15frl.txt', 'blitz_may15frl.txt', 'blitz_jun15frl.txt', 'blitz_jul15frl.txt', 'blitz_aug15frl.txt', 'blitz_sep15frl.txt', 'blitz_oct15frl.txt', 'blitz_nov15frl.txt', 'blitz_dec15frl.txt', 'blitz_jan16frl.txt', 'blitz_feb16frl.txt', 'blitz_mar16frl.txt', 'blitz_apr16frl.txt', 'blitz_may16frl.txt', 'blitz_jun16frl.txt', 'blitz_jul16frl.txt', 'blitz_aug16frl.txt', 'blitz_sep16frl.txt', 'blitz_oct16frl.txt', 'blitz_nov16frl.txt', 'blitz_dec16frl.txt', 'blitz_jan17frl.txt', 'blitz_feb17frl.txt', 'blitz_mar17frl.txt', 'blitz_apr17frl.txt', 'blitz_may17frl.txt', 'blitz_jun17frl.txt', 'blitz_jul17frl.txt', 'blitz_aug17frl.txt', 'blitz_sep17frl.txt', 'blitz_oct17frl.txt', 'blitz_nov17frl.txt', 'blitz_dec17frl.txt', 'blitz_jan18frl.txt', 'blitz_feb18frl.txt', 'blitz_mar18frl.txt', 'blitz_apr18frl.txt', 'blitz_may18frl.txt', 'blitz_jun18frl.txt', 'blitz_jul18frl.txt', 'blitz_aug18frl.txt', 'blitz_sep18frl.txt', 'blitz_oct18frl.txt', 'blitz_nov18frl.txt', 'blitz_dec18frl.txt', 'blitz_jan19frl.txt', 'blitz_feb19frl.txt', 'blitz_mar19frl.txt', 'blitz_apr19frl.txt', 'blitz_may19frl.txt', 'blitz_jun19frl.txt', 'blitz_jul19frl.txt', 'blitz_aug19frl.txt', 'blitz_sep19frl.txt', 'blitz_oct19frl.txt', 'blitz_nov19frl.txt', 'blitz_dec19frl.txt', 'blitz_jan20frl.txt']

# %% [markdown]
# Os arquivos estão localizados em um diretório do git que está armazenado em 'url_dir', logo 'url_dir'+'files' é o local dos arquivos.

# %%
url_dir = 'https://raw.githubusercontent.com/GyaRyu/chessdata/master/data/btz/'
datas = []
for file in files:
  print('\ncarregando arquivo "{}" :{}%...'.format(file,int((100*files.index(file)+1)/len(files))))
  datas.append(pd.read_fwf(url_dir+file))
  pass
print('\ntudo carregado com sucesso!')
# Out:
# carregando arquivo "blitz_jan13frl.txt" :0%...
#
# carregando arquivo "blitz_feb13frl.txt" :1%...
#
# carregando arquivo "blitz_mar13frl.txt" :2%...
#
# carregando arquivo "blitz_apr13frl.txt" :3%...
#
# carregando arquivo "blitz_may13frl.txt" :4%...
#
# carregando arquivo "blitz_jun13frl.txt" :5%...
#
# carregando arquivo "blitz_jul13frl.txt" :7%...
#
# carregando arquivo "blitz_aug13frl.txt" :8%...
#
# carregando arquivo "blitz_sep13frl.txt" :9%...
#
# carregando arquivo "blitz_oct13frl.txt" :10%...
#
# carregando arquivo "blitz_nov13frl.txt" :11%...
#
# carregando arquivo "blitz_dec13frl.txt" :12%...
#
# carregando arquivo "blitz_jan14frl.txt" :14%...
#
# carregando arquivo "blitz_feb14frl.txt" :15%...
#
# carregando arquivo "blitz_mar14frl.txt" :16%...
#
# carregando arquivo "blitz_apr14frl.txt" :17%...
#
# carregando arquivo "blitz_may14frl.txt" :18%...
#
# carregando arquivo "blitz_jun14frl.txt" :20%...
#
# carregando arquivo "blitz_jul14frl.txt" :21%...
#
# carregando arquivo "blitz_aug14frl.txt" :22%...
#
# carregando arquivo "blitz_sep14frl.txt" :23%...
#
# carregando arquivo "blitz_oct14frl.txt" :24%...
#
# carregando arquivo "blitz_nov14frl.txt" :25%...
#
# carregando arquivo "blitz_dec14frl.txt" :27%...
#
# carregando arquivo "blitz_jan15frl.txt" :28%...
#
# carregando arquivo "blitz_feb15frl.txt" :29%...
#
# carregando arquivo "blitz_mar15frl.txt" :30%...
#
# carregando arquivo "blitz_apr15frl.txt" :31%...
#
# carregando arquivo "blitz_may15frl.txt" :32%...
#
# carregando arquivo "blitz_jun15frl.txt" :34%...
#
# carregando arquivo "blitz_jul15frl.txt" :35%...
#
# carregando arquivo "blitz_aug15frl.txt" :36%...
#
# carregando arquivo "blitz_sep15frl.txt" :37%...
#
# carregando arquivo "blitz_oct15frl.txt" :38%...
#
# carregando arquivo "blitz_nov15frl.txt" :40%...
#
# carregando arquivo "blitz_dec15frl.txt" :41%...
#
# carregando arquivo "blitz_jan16frl.txt" :42%...
#
# carregando arquivo "blitz_feb16frl.txt" :43%...
#
# carregando arquivo "blitz_mar16frl.txt" :44%...
#
# carregando arquivo "blitz_apr16frl.txt" :45%...
#
# carregando arquivo "blitz_may16frl.txt" :47%...
#
# carregando arquivo "blitz_jun16frl.txt" :48%...
#
# carregando arquivo "blitz_jul16frl.txt" :49%...
#
# carregando arquivo "blitz_aug16frl.txt" :50%...
#
# carregando arquivo "blitz_sep16frl.txt" :51%...
#
# carregando arquivo "blitz_oct16frl.txt" :52%...
#
# carregando arquivo "blitz_nov16frl.txt" :54%...
#
# carregando arquivo "blitz_dec16frl.txt" :55%...
#
# carregando arquivo "blitz_jan17frl.txt" :56%...
#
# carregando arquivo "blitz_feb17frl.txt" :57%...
#
# carregando arquivo "blitz_mar17frl.txt" :58%...
#
# carregando arquivo "blitz_apr17frl.txt" :60%...
#
# carregando arquivo "blitz_may17frl.txt" :61%...
#
# carregando arquivo "blitz_jun17frl.txt" :62%...
#
# carregando arquivo "blitz_jul17frl.txt" :63%...
#
# carregando arquivo "blitz_aug17frl.txt" :64%...
#
# carregando arquivo "blitz_sep17frl.txt" :65%...
#
# carregando arquivo "blitz_oct17frl.txt" :67%...
#
# carregando arquivo "blitz_nov17frl.txt" :68%...
#
# carregando arquivo "blitz_dec17frl.txt" :69%...
#
# carregando arquivo "blitz_jan18frl.txt" :70%...
#
# carregando arquivo "blitz_feb18frl.txt" :71%...
#
# carregando arquivo "blitz_mar18frl.txt" :72%...
#
# carregando arquivo "blitz_apr18frl.txt" :74%...
#
# carregando arquivo "blitz_may18frl.txt" :75%...
#
# carregando arquivo "blitz_jun18frl.txt" :76%...
#
# carregando arquivo "blitz_jul18frl.txt" :77%...
#
# carregando arquivo "blitz_aug18frl.txt" :78%...
#
# carregando arquivo "blitz_sep18frl.txt" :80%...
#
# carregando arquivo "blitz_oct18frl.txt" :81%...
#
# carregando arquivo "blitz_nov18frl.txt" :82%...
#
# carregando arquivo "blitz_dec18frl.txt" :83%...
#
# carregando arquivo "blitz_jan19frl.txt" :84%...
#
# carregando arquivo "blitz_feb19frl.txt" :85%...
#
# carregando arquivo "blitz_mar19frl.txt" :87%...
#
# carregando arquivo "blitz_apr19frl.txt" :88%...
#
# carregando arquivo "blitz_may19frl.txt" :89%...
#
# carregando arquivo "blitz_jun19frl.txt" :90%...
#
# carregando arquivo "blitz_jul19frl.txt" :91%...
#
# carregando arquivo "blitz_aug19frl.txt" :92%...
#
# carregando arquivo "blitz_sep19frl.txt" :94%...
#
# carregando arquivo "blitz_oct19frl.txt" :95%...
#
# carregando arquivo "blitz_nov19frl.txt" :96%...
#
# carregando arquivo "blitz_dec19frl.txt" :97%...
#
# carregando arquivo "blitz_jan20frl.txt" :98%...
#
# tudo carregado com sucesso!

# %% [markdown]
# Pronto! Todos os arquivos estão carregados!
# Agora vamos trocar as colunas pois no lugar do rating a fide botou os meses com letras maiusculas ou minusculas. Aproveitando também para dropar colunas desnecessárias.

# %%
for idx in range(len(datas)):
  datas[idx] = datas[idx].loc[:, ~datas[idx].columns.str.contains('^Unnamed')]
  datas[idx].drop(columns='FOA', inplace=True, errors='ignore')
  datas[idx].columns = ['id','name','fed','sex','tit','wtit','otit','rat','gms','k','born','flg']
  pass
datas[80].head()
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:4117: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#          id                         name  fed sex  ... gms     k  born  flg
# 0  10207538             A E M, Doshtagir  BAN   M  ...   0  20.0  1974    i
# 1   4804929  A-ALI,Sali Abbas Abdulzahra  IRQ   F  ...   0  20.0  2001   wi
# 2   5700230              A.B, Muhd Yusop  MAS   M  ...   0  20.0  1983    i
# 3  10202650             A.k. Azad, Akand  BAN   M  ...   0  20.0  0000    i
# 4  11201177              A.lateef, Ahmad  BRN   M  ...   0  20.0  0000    i
#
# [5 rows x 12 columns]

# %% [markdown]
# Agora depois de arrumar a cagada da fide podemos selecionar o rating do Carlsen.

# %%
magnus_rat = []
for data in datas:
  data = data.loc[data.name == 'Carlsen, Magnus']
  idx = data.index[0]
  magnus_rat.append(data.loc[idx,'rat'])
  pass

# %%
sns.set_style('dark')
plt.figure(figsize=(60,5))
plt.title('rating do magnus')
plt.xlabel('tempo')
plt.ylabel('rating')
sns.lineplot(x=dates,y=magnus_rat)
